# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
#
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">تمرین عملی 1: طبقه بندی با شبکه های تمام متصل روی مجموعه داده IRIS</div></center></h1>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">صورت مساله</div>
#
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در اولین جلسه کارگاه طبقه بندی با شبکه های تمام متصل را دیدیم.
# <br>
# توصیه می‌شود حتما نوت بوک‌های زیر را قبل از این تمرین مرور کنید:
# </div>
#
# [04_a Gentle Introduction to Keras - Simple neural network(mlp).ipynb](https://nbviewer.jupyter.org/github/alireza-akhavan/SRU-deeplearning-workshop/blob/master/04_a%20Gentle%20Introduction%20to%20Keras%20-%20Simple%20neural%20network%28mlp%29.ipynb)
#
# [05_Dropout.ipynb](https://nbviewer.jupyter.org/github/alireza-akhavan/SRU-deeplearning-workshop/blob/master/05_Dropout.ipynb)
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در این جلسه با داده های تصویری آشنا شدیم. اما در این تمرین برای اینکه بدانیم کاربرد این مباحث در مسائل غیر تصویری نیز هست  از مجموعه داده ی ساختار یافتهiris  شامل 4 ویژگی برای طول و عرض کاسبرگ و گلبرگ استفاده خواهیم کرد که بتوانیم بر اساس این ویژگی ها نوع گل را از 3 کلاس متفاوت تشخیص دهیم.
# </div>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود کتابخانه های مورد نیاز </div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# کتابخانه های مورد نیاز این تمرین لود شده اند
# <br>
# در صورت نیاز میتوانید کتابخانه های بیشتری لود کنید:
# </div>

# %%
import numpy as np
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در این تمرین میخواهیم از مجموعه داده iris استفاده کنیم.
# <br>
# توضیحات این مجموعه داده در سایت آن موجود است:
# </div>
#
# https://archive.ics.uci.edu/ml/datasets/iris
#
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# ویژگی ها و کلاس های این مجموعه داده به شرح زیر است:
# </div>
#
# Attribute Information:
#
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
#
# class:
#
#     Iris Setosa
#     Iris Versicolour
#     Iris Virginica
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# این دیتاست در کتابخانه sklearn موجود است
# <br>
# در قطعه کد زیر ویژگی ها را در x و برچسب یا labelهای متناظر را در y لود شده است.
# </div>

# %%
iris_data = load_iris() # load the iris dataset

x = iris_data.data
y = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 1:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# برچسب یا label های ما در حال حاضر عددی است.
# <br>
# این اعداد 0 تا 2 هستند و به عبارتی 3 حالت مختلف دارند.
# <br>
# این برچسب ها را به فرمت one-hot تبدیل کنید و خروجی را مجدد در y بریزید.
#
# <br>
# <b>راهنمایی: </b>
# از تابع keras.utils.to_categorical استفاده کنید.
# </div>

# %%
y = keras.utils.to_categorical(iris_data.target, num_classes=3)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در زیر داده ها  به داده های test و train تقسیم شده است:
# </div>

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 2:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# یک شبکه با دو hidden-layer در هر لایه 10 نوران و تابع فعالیت relu بسازید. یک لایه Dropout با نرخ 0.5 در لایه آخر ماقبل softmax نیز اضافه کنید.
# </div>

# %%
# Build the model
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">در زیر مدل کامپایل شده است.</div>

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 3:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مدل را با  batch_size=5 و تعداد 200 ایپاک آموزش دهید.
# <br>
# <b>راهنمایی: </b>
# از تابع model.fit استفاده کنید.
# </div>

# %%
# Train the model
model.fit(train_x, train_y, epochs=200, batch_size=5)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 2ms/step - loss: 1.2917 - accuracy: 0.3083
# Epoch 2/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2416 - accuracy: 0.3083
# Epoch 3/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1314 - accuracy: 0.4000
# Epoch 4/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1386 - accuracy: 0.4083
# Epoch 5/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0911 - accuracy: 0.3833
# Epoch 6/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0766 - accuracy: 0.3833
# Epoch 7/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0217 - accuracy: 0.4917
# Epoch 8/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0389 - accuracy: 0.4667
# Epoch 9/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0243 - accuracy: 0.4667
# Epoch 10/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0230 - accuracy: 0.4417
# Epoch 11/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0110 - accuracy: 0.4333
# Epoch 12/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9841 - accuracy: 0.4250
# Epoch 13/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0033 - accuracy: 0.4833
# Epoch 14/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9860 - accuracy: 0.4917
# Epoch 15/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9501 - accuracy: 0.5333
# Epoch 16/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9333 - accuracy: 0.6167
# Epoch 17/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8687 - accuracy: 0.7000
# Epoch 18/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8594 - accuracy: 0.5833
# Epoch 19/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8656 - accuracy: 0.5583
# Epoch 20/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8003 - accuracy: 0.5667
# Epoch 21/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7863 - accuracy: 0.5583
# Epoch 22/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7715 - accuracy: 0.5833
# Epoch 23/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8263 - accuracy: 0.5833
# Epoch 24/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8074 - accuracy: 0.6000
# Epoch 25/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7860 - accuracy: 0.5417
# Epoch 26/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7195 - accuracy: 0.5583
# Epoch 27/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7104 - accuracy: 0.6167
# Epoch 28/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7459 - accuracy: 0.6583
# Epoch 29/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7121 - accuracy: 0.6583
# Epoch 30/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6956 - accuracy: 0.7417
# Epoch 31/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7492 - accuracy: 0.6500
# Epoch 32/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7441 - accuracy: 0.6417
# Epoch 33/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.7000
# Epoch 34/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.6417
# Epoch 35/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6631 - accuracy: 0.6917
# Epoch 36/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6129 - accuracy: 0.7500
# Epoch 37/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5980 - accuracy: 0.7167
# Epoch 38/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.7000
# Epoch 39/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6024 - accuracy: 0.6917
# Epoch 40/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.7417
# Epoch 41/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.8167
# Epoch 42/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5200 - accuracy: 0.7833
# Epoch 43/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5187 - accuracy: 0.8000
# Epoch 44/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5082 - accuracy: 0.7750
# Epoch 45/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.7833
# Epoch 46/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5191 - accuracy: 0.7667
# Epoch 47/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5176 - accuracy: 0.7667
# Epoch 48/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.7750
# Epoch 49/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.7833
# Epoch 50/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4791 - accuracy: 0.7917
# Epoch 51/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.8083
# Epoch 52/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.8000
# Epoch 53/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.7667
# Epoch 54/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5484 - accuracy: 0.7167
# Epoch 55/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7583
# Epoch 56/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4779 - accuracy: 0.7750
# Epoch 57/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.8167
# Epoch 58/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.7917
# Epoch 59/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4375 - accuracy: 0.8000
# Epoch 60/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4634 - accuracy: 0.7667
# Epoch 61/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4375 - accuracy: 0.7750
# Epoch 62/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8333
# Epoch 63/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.7750
# Epoch 64/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8000
# Epoch 65/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4072 - accuracy: 0.7750
# Epoch 66/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.7750
# Epoch 67/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8333
# Epoch 68/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8333
# Epoch 69/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.8083
# Epoch 70/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3396 - accuracy: 0.8750
# Epoch 71/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.7917
# Epoch 72/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7750
# Epoch 73/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.8167
# Epoch 74/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.7833
# Epoch 75/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.8250
# Epoch 76/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8417
# Epoch 77/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 0.7750
# Epoch 78/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.7833
# Epoch 79/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.9083
# Epoch 80/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.7500
# Epoch 81/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.7917
# Epoch 82/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.8583
# Epoch 83/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.8667
# Epoch 84/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8083
# Epoch 85/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3900 - accuracy: 0.8083
# Epoch 86/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3526 - accuracy: 0.8083
# Epoch 87/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8083
# Epoch 88/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8250
# Epoch 89/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8583
# Epoch 90/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4138 - accuracy: 0.7833
# Epoch 91/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3228 - accuracy: 0.8500
# Epoch 92/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8250
# Epoch 93/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3651 - accuracy: 0.8167
# Epoch 94/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.7250
# Epoch 95/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8667
# Epoch 96/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.8833
# Epoch 97/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3624 - accuracy: 0.8083
# Epoch 98/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3076 - accuracy: 0.8667
# Epoch 99/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3677 - accuracy: 0.8000
# Epoch 100/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3911 - accuracy: 0.8083
# Epoch 101/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3073 - accuracy: 0.8417
# Epoch 102/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8083
# Epoch 103/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3434 - accuracy: 0.8500
# Epoch 104/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3118 - accuracy: 0.8583
# Epoch 105/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3068 - accuracy: 0.8667
# Epoch 106/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3247 - accuracy: 0.8417
# Epoch 107/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8333
# Epoch 108/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8000
# Epoch 109/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8250
# Epoch 110/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8583
# Epoch 111/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 0.8500
# Epoch 112/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8583
# Epoch 113/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3048 - accuracy: 0.8667
# Epoch 114/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.8917
# Epoch 115/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.9083
# Epoch 116/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3513 - accuracy: 0.8583
# Epoch 117/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8417
# Epoch 118/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3212 - accuracy: 0.8667
# Epoch 119/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3077 - accuracy: 0.8500
# Epoch 120/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.8417
# Epoch 121/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8833
# Epoch 122/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3083 - accuracy: 0.8583
# Epoch 123/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3013 - accuracy: 0.8417
# Epoch 124/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.8750
# Epoch 125/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8917
# Epoch 126/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8750
# Epoch 127/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8417
# Epoch 128/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.8917
# Epoch 129/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8500
# Epoch 130/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2919 - accuracy: 0.8500
# Epoch 131/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.8750
# Epoch 132/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8167
# Epoch 133/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8250
# Epoch 134/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.8667
# Epoch 135/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.7833
# Epoch 136/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3246 - accuracy: 0.8500
# Epoch 137/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2929 - accuracy: 0.8750
# Epoch 138/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3654 - accuracy: 0.8083
# Epoch 139/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2993 - accuracy: 0.8417
# Epoch 140/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.8583
# Epoch 141/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8500
# Epoch 142/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2880 - accuracy: 0.8917
# Epoch 143/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8417
# Epoch 144/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.8917
# Epoch 145/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8083
# Epoch 146/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8833
# Epoch 147/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 0.8250
# Epoch 148/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.8583
# Epoch 149/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2900 - accuracy: 0.8583
# Epoch 150/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 0.9250
# Epoch 151/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3058 - accuracy: 0.8833
# Epoch 152/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.8667
# Epoch 153/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3028 - accuracy: 0.8667
# Epoch 154/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3160 - accuracy: 0.8583
# Epoch 155/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3205 - accuracy: 0.8750
# Epoch 156/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2467 - accuracy: 0.9083
# Epoch 157/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9083
# Epoch 158/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.8917
# Epoch 159/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9000
# Epoch 160/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.9000
# Epoch 161/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.9083
# Epoch 162/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.9167
# Epoch 163/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.9083
# Epoch 164/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.9083
# Epoch 165/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2421 - accuracy: 0.9083
# Epoch 166/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2557 - accuracy: 0.9083
# Epoch 167/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3184 - accuracy: 0.8667
# Epoch 168/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.9167
# Epoch 169/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.9000
# Epoch 170/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.8583
# Epoch 171/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3086 - accuracy: 0.8667
# Epoch 172/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.9167
# Epoch 173/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9083
# Epoch 174/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9000
# Epoch 175/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2516 - accuracy: 0.9417
# Epoch 176/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.9000
# Epoch 177/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2130 - accuracy: 0.9500
# Epoch 178/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.9083
# Epoch 179/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2671 - accuracy: 0.9250
# Epoch 180/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.9083
# Epoch 181/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2887 - accuracy: 0.9083
# Epoch 182/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2719 - accuracy: 0.9250
# Epoch 183/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8667
# Epoch 184/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.9000
# Epoch 185/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.9167
# Epoch 186/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2777 - accuracy: 0.9083
# Epoch 187/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.9000
# Epoch 188/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2677 - accuracy: 0.9083
# Epoch 189/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.9083
# Epoch 190/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9333
# Epoch 191/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9333
# Epoch 192/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9000
# Epoch 193/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.9167
# Epoch 194/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2966 - accuracy: 0.8750
# Epoch 195/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2360 - accuracy: 0.9083
# Epoch 196/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2789 - accuracy: 0.8750
# Epoch 197/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.9250
# Epoch 198/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2160 - accuracy: 0.9250
# Epoch 199/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.8833
# Epoch 200/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.9083

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 4:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مدل را روی داده های test ارزیابی کنید.
# <br>
# <b>راهنمایی: </b>
# از تابع model.evaluate استفاده کنید.
# </div>

# %%
# Test on unseen data
results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# 1/1 [==============================] - 0s 176ms/step - loss: 0.1290 - accuracy: 0.9333
# Final test set loss: 0.128967
# Final test set accuracy: 0.933333

# %% [markdown]
# <div class="alert alert-block alert-info">
# <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> دوره مقدماتی یادگیری عمیق<br>علیرضا اخوان پور<br>پنج شنبه، ۱۸ و ۲۵ بهمن ۱۳۹۷<br>
# </div>
# <a href="http://class.vision">Class.Vision</a> - <a href="http://AkhavanPour.ir">AkhavanPour.ir</a> - <a href="https://github.com/Alireza-Akhavan/">GitHub</a>
#
# </div>
